# %%
import vtk

from vtk import *

import numpy as np

# %%
with open('atoms-radius.txt') as f:
    radiusDataset = f.read().splitlines()
f.close()

with open('atoms-coordinates.txt') as f:
    atomsCoordinatesDataset = f.read().splitlines()
f.close()

with open('atoms-connections.txt') as f:
    atomsConnectionsDataset = f.read().splitlines()
f.close()

# %%
del radiusDataset[0]
print(len(radiusDataset))
# Out:
# 4634

# %%
del atomsCoordinatesDataset[0]
print(len(atomsCoordinatesDataset))
# Out:
# 4634

# %%
del atomsConnectionsDataset[0]
print(len(atomsConnectionsDataset))
# Out:
# 10409

# %%
points = vtk.vtkPoints()
print(points.GetNumberOfPoints())
for coord in atomsCoordinatesDataset:
    pointData = coord.split(' ')
    numPointData = [float(pointData[0]), float(pointData[1]), float(pointData[2])]
    points.InsertNextPoint(numPointData[:])
#print(pointData[0])
#points.addPoint(0, pointData[0], pointData[1], pointData[2])
print(points.GetNumberOfPoints())
# Out:
# 0
# 4634

# %%
#Parse atoms connections
connections = []
for i in range(0, len(atomsCoordinatesDataset)):
    connections.append([])
    
print(len(connections))

lines = vtk.vtkCellArray()
for line in atomsConnectionsDataset:
    stringList = line.split(' ')
    position = int(stringList[0])
    value = int(stringList[1])
    connections[position].append(value)
    
for connection in connections:
    if connection != []:
        #print(connection)
        lines.InsertNextCell(len(connection))
        for index in connection:
            lines.InsertCellPoint(index)
            
print(lines)
# Out:
# 4634
# vtkCellArray (0x7fc2d102db80)
#   Debug: Off
#   Modified Time: 77
#   Reference Count: 1
#   Registered Events: (none)
#   Number Of Cells: 3216
#   Insert Location: 13625
#   Traversal Location: 0

# %%
scalars = vtk.vtkFloatArray()

# %%
'''for valueStr in radiusDataset:
    value = float(valueStr)
    #scalars.InsertTuple1(value,value)
    scalars.InsertTuple(i, value)
    i = i + 1
    print(valueStr)
'''
for valueStr in radiusDataset:
    value = float(valueStr)
    scalars.InsertNextValue(value)
    
print(scalars)
# Out:
# vtkFloatArray (0x7fc2cdb9c5c0)
#   Debug: Off
#   Modified Time: 80
#   Reference Count: 1
#   Registered Events: (none)
#   Name: (none)
#   Data type: float
#   Size: 8191
#   MaxId: 4633
#   NumberOfComponents: 1
#   Information: 0x0
#   Name: (none)
#   Number Of Components: 1
#   Number Of Tuples: 4634
#   Size: 8191
#   MaxId: 4633
#   LookupTable: (none)

# %%
renderer = vtk.vtkRenderer()

#elev = vtk.vtkElevationFilter()
#elev.SetLowPoint(-2,-2,0)
#elev.SetHighPoint(2,2,0)
glyph = vtk.vtkGlyph3D()
#glyph.SetInputConnection(elev.GetOutputPort())

mapper = vtk.vtkPolyDataMapper()
#mapper.SetInputConnection(glyph.GetOutputPort())

#polydata.GetCellData().SetScalars(scalars);
'''for i in range(0, points.GetNumberOfPoints()):
    point = points.GetPoint(i)
    sphere = vtk.vtkSphereSource()
    sphere.SetRadius(scalars.GetValue(i))
    print(scalars.GetValue(i))
    #sphere.SetRadius(1)
    glyph.SetInputData(i, sphere.GetOutput())
    mapper.SetInputConnection(sphere.GetOutputPort())
    sphereActor = vtk.vtkActor()
    sphereActor.SetPosition(point)
    radiiValue = scalars.GetValue(i)
    if radiiValue < 0.4:
        sphereActor.GetProperty().SetColor(scalars.GetValue(i), 0, 0)
    elif radiiValue < 0.7: 
        sphereActor.GetProperty().SetColor(0, 0, scalars.GetValue(i))
    else:
        sphereActor.GetProperty().SetColor(0, scalars.GetValue(i), 0)
    sphereActor.SetMapper(mapper)
    renderer.AddActor(sphereActor)
    
'''

for i in range(0, points.GetNumberOfPoints()):
    point = points.GetPoint(i)
    sphere = vtk.vtkSphereSource()
    sphere.SetRadius(scalars.GetValue(i) / 2)
    #sphere.SetRadius(1)
    #print(scalars.GetValue(i))

    glyph.SetInputConnection(sphere.GetOutputPort())
    #glyph.SetVectorModeToUseNormal()
    #glyph.SetScaleModeToScaleByVector()
    glyph.SetScaleFactor(0.1)

    #apd = vtk.vtkAppendPolyData()
    #apd.AddInputConnection(glyph.GetOutputPort())
    #apd.AddInputConnection(sphere.GetOutputPort())

    mapper = vtk.vtkPolyDataMapper()
    mapper.SetInputConnection(sphere.GetOutputPort())
    
    mapper.SetColorModeToMapScalars();
    #mapper.SetScalarModeToUsePointFieldData()
    #mapper.SetColorModeToMapScalars()
    #mapper.ScalarVisibilityOn()

    actor = vtk.vtkActor()
    actor.SetMapper(mapper)
    actor.SetPosition(point)
    actor.VisibilityOn()
    
    radiiValue = scalars.GetValue(i)
    
    lut = vtkColorTransferFunction()
    #lut.SetNumberOfTableValues(4)
    lut.SetColorSpaceToRGB()
    lut.AddRGBPoint(0.3,1,1,1)
    lut.AddRGBPoint(0.7,1,0,0)
    lut.AddRGBPoint(0.78,0,0,1)
    lut.AddRGBPoint(2,0,1,0)
    lut.SetScaleToLinear()
    
    
    print(lut.GetColor(0))
    actor.GetProperty().SetColor(lut.GetColor(scalars.GetValue(i)))
    print(lut)
    
    '''if radiiValue > 1.5:
        actor.GetProperty().SetColor(0, scalars.GetValue(i) * 0.5, 0) 
    elif radiiValue > 0.745:
        
        actor.GetProperty().SetColor(0, 0, scalars.GetValue(i))   
    elif radiiValue > 0.4: 
        
        actor.GetProperty().SetColor(scalars.GetValue(i), 0, 0) 
    else:
        actor.GetProperty().SetColor(1, 1, 1)
    '''
    
    mapper.SetLookupTable(lut)
    renderer.AddActor(actor)

#print(actor.GetMapper())
#glyph.Update()
# Out:
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2cdf5cd00)
#   Debug: Off
#   Modified Time: 290
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2cdba1ae0)
#   Debug: Off
#   Modified Time: 399
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2cdba68c0)
#   Debug: Off
#   Modified Time: 508
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2cdbab630)
#   Debug: Off
#   Modified Time: 617
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2cdbb03a0)
#   Debug: Off
#   Modified Time: 726
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2cdbb5110)
#   Debug: Off
#   Modified Time: 835
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d1033600)
#   Debug: Off
#   Modified Time: 944
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d1038440)
#   Debug: Off
#   Modified Time: 1053
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d103d270)
#   Debug: Off
#   Modified Time: 1162
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d10420a0)
#   Debug: Off
#   Modified Time: 1271
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d1046ed0)
#   Debug: Off
#   Modified Time: 1380
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d112a140)
#   Debug: Off
#   Modified Time: 1489
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d112efb0)
#   Debug: Off
#   Modified Time: 1598
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d1133de0)
#   Debug: Off
#   Modified Time: 1707
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d1138c10)
#   Debug: Off
#   Modified Time: 1816
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d113da40)
#   Debug: Off
#   Modified Time: 1925
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d1142870)
#   Debug: Off
#   Modified Time: 2034
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d11476a0)
#   Debug: Off
#   Modified Time: 2143
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d114c4d0)
#   Debug: Off
#   Modified Time: 2252
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d1151300)
#   Debug: Off
#   Modified Time: 2361
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d1156130)
#   Debug: Off
#   Modified Time: 2470
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d115af60)
#   Debug: Off
#   Modified Time: 2579
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d115fd90)
#   Debug: Off
#   Modified Time: 2688
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d1164bc0)
#   Debug: Off
#   Modified Time: 2797
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d11699f0)
#   Debug: Off
#   Modified Time: 2906
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d116e820)
#   Debug: Off
#   Modified Time: 3015
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d1173650)
#   Debug: Off
#   Modified Time: 3124
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d1178480)
#   Debug: Off
#   Modified Time: 3233
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d117d2b0)
#   Debug: Off
#   Modified Time: 3342
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d11820e0)
#   Debug: Off
#   Modified Time: 3451
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d1186f10)
#   Debug: Off
#   Modified Time: 3560
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d118bd40)
#   Debug: Off
#   Modified Time: 3669
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d1190b70)
#   Debug: Off
#   Modified Time: 3778
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d11959a0)
#   Debug: Off
#   Modified Time: 3887
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d119a7d0)
#   Debug: Off
#   Modified Time: 3996
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d119f600)
#   Debug: Off
#   Modified Time: 4105
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d11a4430)
#   Debug: Off
#   Modified Time: 4214
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d11a9260)
#   Debug: Off
#   Modified Time: 4323
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d11ae090)
#   Debug: Off
#   Modified Time: 4432
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d11b2ec0)
#   Debug: Off
#   Modified Time: 4541
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d11b7cd0)
#   Debug: Off
#   Modified Time: 4650
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2cdbba060)
#   Debug: Off
#   Modified Time: 4759
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2cdbbef00)
#   Debug: Off
#   Modified Time: 4868
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2cd80b7c0)
#   Debug: Off
#   Modified Time: 4977
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d11bc7a0)
#   Debug: Off
#   Modified Time: 5086
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d11c1660)
#   Debug: Off
#   Modified Time: 5195
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d11c6490)
#   Debug: Off
#   Modified Time: 5304
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d11cb2c0)
#   Debug: Off
#   Modified Time: 5413
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d11d00c0)
#   Debug: Off
#   Modified Time: 5522
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d11d4ef0)
#   Debug: Off
#   Modified Time: 5631
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d11d9d20)
#   Debug: Off
#   Modified Time: 5740
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d11deb50)
#   Debug: Off
#   Modified Time: 5849
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d11e3980)
#   Debug: Off
#   Modified Time: 5958
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d11e87b0)
#   Debug: Off
#   Modified Time: 6067
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d11ed5e0)
#   Debug: Off
#   Modified Time: 6176
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d11f2410)
#   Debug: Off
#   Modified Time: 6285
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d11f7240)
#   Debug: Off
#   Modified Time: 6394
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d1200000)
#   Debug: Off
#   Modified Time: 6503
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d1204e20)
#   Debug: Off
#   Modified Time: 6612
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d1209c50)
#   Debug: Off
#   Modified Time: 6721
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d120ea80)
#   Debug: Off
#   Modified Time: 6830
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d12138b0)
#   Debug: Off
#   Modified Time: 6939
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d12186e0)
#   Debug: Off
#   Modified Time: 7048
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d121d510)
#   Debug: Off
#   Modified Time: 7157
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d1222340)
#   Debug: Off
#   Modified Time: 7266
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d1227170)
#   Debug: Off
#   Modified Time: 7375
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d122bfa0)
#   Debug: Off
#   Modified Time: 7484
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
# ...
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d595d380)
#   Debug: Off
#   Modified Time: 427025
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d59621b0)
#   Debug: Off
#   Modified Time: 427134
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d5966fe0)
#   Debug: Off
#   Modified Time: 427243
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d596be10)
#   Debug: Off
#   Modified Time: 427352
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d5970c40)
#   Debug: Off
#   Modified Time: 427461
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d5975a70)
#   Debug: Off
#   Modified Time: 427570
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d4fd6320)
#   Debug: Off
#   Modified Time: 427679
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d5504250)
#   Debug: Off
#   Modified Time: 427788
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d5509080)
#   Debug: Off
#   Modified Time: 427897
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d550deb0)
#   Debug: Off
#   Modified Time: 428006
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d5512ce0)
#   Debug: Off
#   Modified Time: 428115
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d5517b10)
#   Debug: Off
#   Modified Time: 428224
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d551c940)
#   Debug: Off
#   Modified Time: 428333
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d5521770)
#   Debug: Off
#   Modified Time: 428442
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d55265a0)
#   Debug: Off
#   Modified Time: 428551
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d552b3d0)
#   Debug: Off
#   Modified Time: 428660
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d5530200)
#   Debug: Off
#   Modified Time: 428769
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d5535030)
#   Debug: Off
#   Modified Time: 428878
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d5539e60)
#   Debug: Off
#   Modified Time: 428987
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d553ec90)
#   Debug: Off
#   Modified Time: 429096
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fc2d5543ac0)
#   Debug: Off
#   Modified Time: 429205
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# vtkPolyData is a data object that is a concrete implementation of vtkDataSet.
# vtkPolyData represents a geometric structure consisting of vertices, lines,
# polygons, and/or triangle strips
polygon = vtk.vtkPolyData()
polygon.SetPoints(points)
polygon.SetLines(lines)
#polygon.GetCellData().SetScalars(scalars)

tubeFilter = vtk.vtkTubeFilter()
tubeFilter.SetInputData(polygon)
tubeFilter.SetNumberOfSides(5);
tubeFilter.SetVaryRadiusToVaryRadiusOff()
tubeFilter.SetRadius(0.1)

tubeMapper = vtk.vtkPolyDataMapper()
tubeMapper.SetInputConnection(tubeFilter.GetOutputPort())
tubeMapper.Update()


actor = vtk.vtkActor()
actor.SetMapper(tubeMapper)
#actor.SetPosition(point)
actor.VisibilityOn()
renderer.AddActor(actor)

# %%
#sphere = []
#for spherePosition in atomsCoordinatesDataset:
#    sphere = vtkSphereSource()
#    sphere.SetRadius(scalars.GetValue(0))
#    #polygon = sphere.GetOutput()

#print(sphere)

# %%
# outline
outline = vtk.vtkOutlineFilter()
if vtk.VTK_MAJOR_VERSION <= 5:
    outline.SetInputData(tubeFilter)
else:
    outline.SetInputConnection(tubeFilter.GetOutputPort())
mapper2 = vtk.vtkPolyDataMapper()
if vtk.VTK_MAJOR_VERSION <= 5:
    mapper2.SetInput(outline.GetOutput())
else:
    mapper2.SetInputConnection(outline.GetOutputPort())
    
actor2 = vtk.vtkActor()
actor2.GetProperty().SetColor(0, 0, 0)
actor2.SetMapper(mapper2)

renderer.AddActor(actor2)

# %%
# vtkPolyDataMapper is a class that maps polygonal data (i.e., vtkPolyData)
# to graphics primitives
'''polygonMapper = vtk.vtkPolyDataMapper()
if vtk.VTK_MAJOR_VERSION <= 5:
    polygonMapper.SetInputConnection(polygon.GetProducerPort())
else:
    polygonMapper.SetInputData(polygon)
    polygonMapper.Update()
'''
# Out:
# 'polygonMapper = vtk.vtkPolyDataMapper()\nif vtk.VTK_MAJOR_VERSION <= 5:\n    polygonMapper.SetInputConnection(polygon.GetProducerPort())\nelse:\n    polygonMapper.SetInputData(polygon)\n    polygonMapper.Update()\n'

# %%
# Create an actor to represent the polygon. The actor orchestrates rendering of
# the mapper's graphics primitives. An actor also refers to properties via a
# vtkProperty instance, and includes an internal transformation matrix. We
# set this actor's mapper to be polygonMapper which we created above.
#polygonActor = vtk.vtkActor()
#polygonActor.SetMapper(polygonMapper)
#polygonActor.GetProperty().SetColor(1, 1, 1)

# %%
#glyph = vtk.vtkGlyph3D()
#glyph.SetInputData(polygon)

# %%
# Create the Renderer and assign actors to it. A renderer is like a
# viewport. It is part or all of a window on the screen and it is
# responsible for drawing the actors it has.  We also set the
# background color here.
#renderer = vtk.vtkRenderer()

# %%
#renderer.AddActor(polygonActor)

# %%
renderer.SetBackground(0.3, 0.3, 0.3)

# %%
# Automatically set up the camera based on the visible actors.
# The camera will reposition itself to view the center point of the actors,
# and move along its initial view plane normal
# (i.e., vector defined from camera position to focal point) so that all of the
# actors can be seen.
renderer.ResetCamera()

# %%
# Finally we create the render window which will show up on the screen
# We put our renderer into the render window using AddRenderer. We
# also set the size to be 300 pixels by 300.
renWin = vtk.vtkRenderWindow()
renWin.AddRenderer(renderer)
renWin.SetSize(800, 600)
 
# The vtkRenderWindowInteractor class watches for events (e.g., keypress,
# mouse) in the vtkRenderWindow. These events are translated into
# event invocations that VTK understands (see VTK/Common/vtkCommand.h
# for all events that VTK processes). Then observers of these VTK
# events can process them as appropriate.
iren = vtk.vtkRenderWindowInteractor()
iren.SetRenderWindow(renWin)
iren.Initialize()
iren.Start()
 
# There is no explicit need to free any objects at this point.
# Once Python exits, memory is automatically freed.
