# %%
import vtk

from vtk import *

import numpy as np

# %%
with open('atoms-radius.txt') as f:
    radiusDataset = f.read().splitlines()
f.close()

with open('atoms-coordinates.txt') as f:
    atomsCoordinatesDataset = f.read().splitlines()
f.close()

with open('atoms-connections.txt') as f:
    atomsConnectionsDataset = f.read().splitlines()
f.close()

# %%
del radiusDataset[0]
print(len(radiusDataset))
# Out:
# 4634

# %%
del atomsCoordinatesDataset[0]
print(len(atomsCoordinatesDataset))
# Out:
# 4634

# %%
del atomsConnectionsDataset[0]
print(len(atomsConnectionsDataset))
# Out:
# 10409

# %%
points = vtk.vtkPoints()
print(points.GetNumberOfPoints())
for coord in atomsCoordinatesDataset:
    pointData = coord.split(' ')
    numPointData = [float(pointData[0]), float(pointData[1]), float(pointData[2])]
    points.InsertNextPoint(numPointData[:])
#print(pointData[0])
#points.addPoint(0, pointData[0], pointData[1], pointData[2])
print(points.GetNumberOfPoints())
# Out:
# 0
# 4634

# %%
#Parse atoms connections
connections = []
for i in range(0, len(atomsCoordinatesDataset)):
    connections.append([])
    
print(len(connections))

lines = vtk.vtkCellArray()
for line in atomsConnectionsDataset:
    stringList = line.split(' ')
    position = int(stringList[0])
    value = int(stringList[1])
    connections[position].append(value)
    
for connection in connections:
    if connection != []:
        #print(connection)
        lines.InsertNextCell(len(connection))
        for index in connection:
            lines.InsertCellPoint(index)
            
print(lines)
# Out:
# 4634
# vtkCellArray (0x7fe11984f410)
#   Debug: Off
#   Modified Time: 77
#   Reference Count: 1
#   Registered Events: (none)
#   Number Of Cells: 3216
#   Insert Location: 13625
#   Traversal Location: 0

# %%
scalars = vtk.vtkFloatArray()

# %%
'''for valueStr in radiusDataset:
    value = float(valueStr)
    #scalars.InsertTuple1(value,value)
    scalars.InsertTuple(i, value)
    i = i + 1
    print(valueStr)
'''
for valueStr in radiusDataset:
    value = float(valueStr)
    scalars.InsertNextValue(value)
    
print(scalars)
# Out:
# vtkFloatArray (0x7fe1166a7660)
#   Debug: Off
#   Modified Time: 80
#   Reference Count: 1
#   Registered Events: (none)
#   Name: (none)
#   Data type: float
#   Size: 8191
#   MaxId: 4633
#   NumberOfComponents: 1
#   Information: 0x0
#   Name: (none)
#   Number Of Components: 1
#   Number Of Tuples: 4634
#   Size: 8191
#   MaxId: 4633
#   LookupTable: (none)

# %%
renderer = vtk.vtkRenderer()

#elev = vtk.vtkElevationFilter()
#elev.SetLowPoint(-2,-2,0)
#elev.SetHighPoint(2,2,0)
glyph = vtk.vtkGlyph3D()
#glyph.SetInputConnection(elev.GetOutputPort())

mapper = vtk.vtkPolyDataMapper()
#mapper.SetInputConnection(glyph.GetOutputPort())

#polydata.GetCellData().SetScalars(scalars);
'''for i in range(0, points.GetNumberOfPoints()):
    point = points.GetPoint(i)
    sphere = vtk.vtkSphereSource()
    sphere.SetRadius(scalars.GetValue(i))
    print(scalars.GetValue(i))
    #sphere.SetRadius(1)
    glyph.SetInputData(i, sphere.GetOutput())
    mapper.SetInputConnection(sphere.GetOutputPort())
    sphereActor = vtk.vtkActor()
    sphereActor.SetPosition(point)
    radiiValue = scalars.GetValue(i)
    if radiiValue < 0.4:
        sphereActor.GetProperty().SetColor(scalars.GetValue(i), 0, 0)
    elif radiiValue < 0.7: 
        sphereActor.GetProperty().SetColor(0, 0, scalars.GetValue(i))
    else:
        sphereActor.GetProperty().SetColor(0, scalars.GetValue(i), 0)
    sphereActor.SetMapper(mapper)
    renderer.AddActor(sphereActor)
    
'''

for i in range(0, points.GetNumberOfPoints()):
    point = points.GetPoint(i)
    sphere = vtk.vtkSphereSource()
    sphere.SetRadius(scalars.GetValue(i) / 2)
    #sphere.SetRadius(1)
    #print(scalars.GetValue(i))

    glyph.SetInputConnection(sphere.GetOutputPort())
    #glyph.SetVectorModeToUseNormal()
    #glyph.SetScaleModeToScaleByVector()
    glyph.SetScaleFactor(0.1)

    #apd = vtk.vtkAppendPolyData()
    #apd.AddInputConnection(glyph.GetOutputPort())
    #apd.AddInputConnection(sphere.GetOutputPort())

    mapper = vtk.vtkPolyDataMapper()
    mapper.SetInputConnection(sphere.GetOutputPort())
    
    mapper.SetColorModeToMapScalars();
    #mapper.SetScalarModeToUsePointFieldData()
    #mapper.SetColorModeToMapScalars()
    #mapper.ScalarVisibilityOn()

    actor = vtk.vtkActor()
    actor.SetMapper(mapper)
    actor.SetPosition(point)
    actor.VisibilityOn()
    
    radiiValue = scalars.GetValue(i)
    
    lut = vtkColorTransferFunction()
    #lut.SetNumberOfTableValues(4)
    lut.SetColorSpaceToRGB()
    lut.AddRGBPoint(0.3,1,1,1)
    lut.AddRGBPoint(0.7,1,0,0)
    lut.AddRGBPoint(0.78,0,0,1)
    lut.AddRGBPoint(2,0,1,0)
    lut.SetScaleToLinear()
    
    
    print(lut.GetColor(0))
    actor.GetProperty().SetColor(lut.GetColor(scalars.GetValue(i)))
    print(lut)
    
    '''if radiiValue > 1.5:
        actor.GetProperty().SetColor(0, scalars.GetValue(i) * 0.5, 0) 
    elif radiiValue > 0.745:
        
        actor.GetProperty().SetColor(0, 0, scalars.GetValue(i))   
    elif radiiValue > 0.4: 
        
        actor.GetProperty().SetColor(scalars.GetValue(i), 0, 0) 
    else:
        actor.GetProperty().SetColor(1, 1, 1)
    '''
    
    mapper.SetLookupTable(lut)
    renderer.AddActor(actor)

#print(actor.GetMapper())
#glyph.Update()
# Out:
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe1166c7fb0)
#   Debug: Off
#   Modified Time: 290
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe1166ccef0)
#   Debug: Off
#   Modified Time: 399
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe1166d1d20)
#   Debug: Off
#   Modified Time: 508
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe1166d6b50)
#   Debug: Off
#   Modified Time: 617
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe1166db980)
#   Debug: Off
#   Modified Time: 726
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe1166e07b0)
#   Debug: Off
#   Modified Time: 835
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe1166e55e0)
#   Debug: Off
#   Modified Time: 944
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe1166ea410)
#   Debug: Off
#   Modified Time: 1053
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe1166ef240)
#   Debug: Off
#   Modified Time: 1162
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe1166f4070)
#   Debug: Off
#   Modified Time: 1271
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe1166f8ea0)
#   Debug: Off
#   Modified Time: 1380
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe119901c50)
#   Debug: Off
#   Modified Time: 1489
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe119906a80)
#   Debug: Off
#   Modified Time: 1598
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe11990b8b0)
#   Debug: Off
#   Modified Time: 1707
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe1199106e0)
#   Debug: Off
#   Modified Time: 1816
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe119915510)
#   Debug: Off
#   Modified Time: 1925
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe11991a340)
#   Debug: Off
#   Modified Time: 2034
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe116564150)
#   Debug: Off
#   Modified Time: 2143
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe116568f30)
#   Debug: Off
#   Modified Time: 2252
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe1198a41c0)
#   Debug: Off
#   Modified Time: 2361
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe1198a9050)
#   Debug: Off
#   Modified Time: 2470
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe1198ade80)
#   Debug: Off
#   Modified Time: 2579
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe1198b2cb0)
#   Debug: Off
#   Modified Time: 2688
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe1198b7ae0)
#   Debug: Off
#   Modified Time: 2797
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe1198bc910)
#   Debug: Off
#   Modified Time: 2906
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe1198c1740)
#   Debug: Off
#   Modified Time: 3015
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe1198c6570)
#   Debug: Off
#   Modified Time: 3124
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe1198cb3a0)
#   Debug: Off
#   Modified Time: 3233
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe1198d01d0)
#   Debug: Off
#   Modified Time: 3342
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe1198d5000)
#   Debug: Off
#   Modified Time: 3451
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe1198d9e30)
#   Debug: Off
#   Modified Time: 3560
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe1198dec60)
#   Debug: Off
#   Modified Time: 3669
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe1198e3a90)
#   Debug: Off
#   Modified Time: 3778
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe1198e88c0)
#   Debug: Off
#   Modified Time: 3887
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe1198ed6f0)
#   Debug: Off
#   Modified Time: 3996
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe1198f2520)
#   Debug: Off
#   Modified Time: 4105
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe1198f7350)
#   Debug: Off
#   Modified Time: 4214
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe119a00100)
#   Debug: Off
#   Modified Time: 4323
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe119a04f30)
#   Debug: Off
#   Modified Time: 4432
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe119a09d60)
#   Debug: Off
#   Modified Time: 4541
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe119a0eb90)
#   Debug: Off
#   Modified Time: 4650
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe119a139c0)
#   Debug: Off
#   Modified Time: 4759
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe119a187f0)
#   Debug: Off
#   Modified Time: 4868
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe119a1d620)
#   Debug: Off
#   Modified Time: 4977
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe119a22450)
#   Debug: Off
#   Modified Time: 5086
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe119a27280)
#   Debug: Off
#   Modified Time: 5195
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe119a2c0b0)
#   Debug: Off
#   Modified Time: 5304
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe119a30ee0)
#   Debug: Off
#   Modified Time: 5413
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe119a35d10)
#   Debug: Off
#   Modified Time: 5522
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe119a3ab40)
#   Debug: Off
#   Modified Time: 5631
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe119a3f970)
#   Debug: Off
#   Modified Time: 5740
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe119a447a0)
#   Debug: Off
#   Modified Time: 5849
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe119a495d0)
#   Debug: Off
#   Modified Time: 5958
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe119a4e400)
#   Debug: Off
#   Modified Time: 6067
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe119a53230)
#   Debug: Off
#   Modified Time: 6176
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe119a58060)
#   Debug: Off
#   Modified Time: 6285
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe119a5ce90)
#   Debug: Off
#   Modified Time: 6394
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe119a61cc0)
#   Debug: Off
#   Modified Time: 6503
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe119a66af0)
#   Debug: Off
#   Modified Time: 6612
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe119a6b920)
#   Debug: Off
#   Modified Time: 6721
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe119a70750)
#   Debug: Off
#   Modified Time: 6830
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe119a75580)
#   Debug: Off
#   Modified Time: 6939
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe119a7a3b0)
#   Debug: Off
#   Modified Time: 7048
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe119a7f1e0)
#   Debug: Off
#   Modified Time: 7157
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe119a84010)
#   Debug: Off
#   Modified Time: 7266
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe119a88e40)
#   Debug: Off
#   Modified Time: 7375
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe119a8dc70)
#   Debug: Off
#   Modified Time: 7484
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
# ...
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe11ddc3140)
#   Debug: Off
#   Modified Time: 429314
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe11ddc7f70)
#   Debug: Off
#   Modified Time: 429423
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe11ddccda0)
#   Debug: Off
#   Modified Time: 429532
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe11ddd1bd0)
#   Debug: Off
#   Modified Time: 429641
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe11ddd6a00)
#   Debug: Off
#   Modified Time: 429750
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe11dddb830)
#   Debug: Off
#   Modified Time: 429859
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe11dde0630)
#   Debug: Off
#   Modified Time: 429968
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe11dde5460)
#   Debug: Off
#   Modified Time: 430077
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe11ddea290)
#   Debug: Off
#   Modified Time: 430186
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe11ddef0c0)
#   Debug: Off
#   Modified Time: 430295
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe11ddf3ef0)
#   Debug: Off
#   Modified Time: 430404
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe11ddf8d20)
#   Debug: Off
#   Modified Time: 430513
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe11e201ad0)
#   Debug: Off
#   Modified Time: 430622
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe11e206900)
#   Debug: Off
#   Modified Time: 430731
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe11e20b730)
#   Debug: Off
#   Modified Time: 430840
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe11e210560)
#   Debug: Off
#   Modified Time: 430949
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe11e215390)
#   Debug: Off
#   Modified Time: 431058
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe11e21a1c0)
#   Debug: Off
#   Modified Time: 431167
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe11e21eff0)
#   Debug: Off
#   Modified Time: 431276
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe11e223e20)
#   Debug: Off
#   Modified Time: 431385
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# vtkColorTransferFunction (0x7fe11e228c50)
#   Debug: Off
#   Modified Time: 431494
#   Reference Count: 1
#   Registered Events: (none)
#   Alpha: 1
#   VectorMode: Component
#   VectorComponent: 0
#   VectorSize: -1
#   IndexedLookup: OFF
#   AnnotatedValues: 0 entries.
#   Size: 4
#   Clamping: On
#   Color Space: RGB
#   Scale: Linear
#   Range: 0.3 to 2
#   AllowDuplicateScalars: 0
#   NanColor: 0.5, 0, 0
#   BelowRangeColor: (0, 0, 0)
#   UseBelowRangeColor: OFF
#   ABoveRangeColor: (1, 1, 1)
#   UseAboveRangeColor: OFF
#     0 X: 0.3 R: 1 G: 1 B: 1 Sharpness: 0 Midpoint: 0.5
#     1 X: 0.7 R: 1 G: 0 B: 0 Sharpness: 0 Midpoint: 0.5
#     2 X: 0.78 R: 0 G: 0 B: 1 Sharpness: 0 Midpoint: 0.5
#     3 X: 2 R: 0 G: 1 B: 0 Sharpness: 0 Midpoint: 0.5
#
#
# (1.0, 1.0, 1.0)
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# vtkPolyData is a data object that is a concrete implementation of vtkDataSet.
# vtkPolyData represents a geometric structure consisting of vertices, lines,
# polygons, and/or triangle strips
polygon = vtk.vtkPolyData()
polygon.SetPoints(points)
polygon.SetLines(lines)
#polygon.GetCellData().SetScalars(scalars)

tubeFilter = vtk.vtkTubeFilter()
tubeFilter.SetInputData(polygon)
tubeFilter.SetNumberOfSides(5);
tubeFilter.SetVaryRadiusToVaryRadiusOff()
tubeFilter.SetRadius(0.1)

tubeMapper = vtk.vtkPolyDataMapper()
tubeMapper.SetInputConnection(tubeFilter.GetOutputPort())
tubeMapper.Update()


actor = vtk.vtkActor()
actor.SetMapper(tubeMapper)
#actor.SetPosition(point)
actor.VisibilityOn()
renderer.AddActor(actor)

# %%
#sphere = []
#for spherePosition in atomsCoordinatesDataset:
#    sphere = vtkSphereSource()
#    sphere.SetRadius(scalars.GetValue(0))
#    #polygon = sphere.GetOutput()

#print(sphere)

# %%
# vtkPolyDataMapper is a class that maps polygonal data (i.e., vtkPolyData)
# to graphics primitives
'''polygonMapper = vtk.vtkPolyDataMapper()
if vtk.VTK_MAJOR_VERSION <= 5:
    polygonMapper.SetInputConnection(polygon.GetProducerPort())
else:
    polygonMapper.SetInputData(polygon)
    polygonMapper.Update()
'''
# Out:
# 'polygonMapper = vtk.vtkPolyDataMapper()\nif vtk.VTK_MAJOR_VERSION <= 5:\n    polygonMapper.SetInputConnection(polygon.GetProducerPort())\nelse:\n    polygonMapper.SetInputData(polygon)\n    polygonMapper.Update()\n'

# %%
# Create an actor to represent the polygon. The actor orchestrates rendering of
# the mapper's graphics primitives. An actor also refers to properties via a
# vtkProperty instance, and includes an internal transformation matrix. We
# set this actor's mapper to be polygonMapper which we created above.
#polygonActor = vtk.vtkActor()
#polygonActor.SetMapper(polygonMapper)
#polygonActor.GetProperty().SetColor(1, 1, 1)

# %%
#glyph = vtk.vtkGlyph3D()
#glyph.SetInputData(polygon)

# %%
# Create the Renderer and assign actors to it. A renderer is like a
# viewport. It is part or all of a window on the screen and it is
# responsible for drawing the actors it has.  We also set the
# background color here.
#renderer = vtk.vtkRenderer()

# %%
#renderer.AddActor(polygonActor)

# %%
renderer.SetBackground(0.3, 0.3, 0.3)

# %%
# Automatically set up the camera based on the visible actors.
# The camera will reposition itself to view the center point of the actors,
# and move along its initial view plane normal
# (i.e., vector defined from camera position to focal point) so that all of the
# actors can be seen.
renderer.ResetCamera()

# %%
# Finally we create the render window which will show up on the screen
# We put our renderer into the render window using AddRenderer. We
# also set the size to be 300 pixels by 300.
renWin = vtk.vtkRenderWindow()
renWin.AddRenderer(renderer)
renWin.SetSize(800, 600)
 
# The vtkRenderWindowInteractor class watches for events (e.g., keypress,
# mouse) in the vtkRenderWindow. These events are translated into
# event invocations that VTK understands (see VTK/Common/vtkCommand.h
# for all events that VTK processes). Then observers of these VTK
# events can process them as appropriate.
iren = vtk.vtkRenderWindowInteractor()
iren.SetRenderWindow(renWin)
iren.Initialize()
iren.Start()
 
# There is no explicit need to free any objects at this point.
# Once Python exits, memory is automatically freed.
